# %% [markdown]
# # Model Training
#   * All the codes and preprocessed data are uploaded to Google Drive
#   * Colab mount the Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Train code location

# %%
# %cd /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD
# Out:
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD

# %% [markdown]
# ## Train model
#
#
# ```
# usage: python3 main.py [-h] [--config CONFIG] [--expansion EXPANSION] [--percentage_usage PERCENTAGE_USAGE]
#
# options:
#   -h, --help            show this help message and exit
#   --config CONFIG       config
#   --expansion EXPANSION
#                         expansions to decide the width of the model
#   --percentage_usage PERCENTAGE_USAGE
#                         percentage of data to use for training
# ```

# %%
# !python3 main.py --config config_200_alex
# Out:
# Baseline AlexNet Archetecture!
# has module!
# In total  135  patients in training set
# Epoch: [0][0/35]	Time 6.348 (6.348)	Data 1.551 (1.551)	Loss 1.0985 (1.0985)	Accuracy 50.000
# Epoch: [0][10/35]	Time 2.785 (2.731)	Data 0.010 (0.150)	Loss 1.0970 (1.0986)	Accuracy 50.000
# Epoch: [0][20/35]	Time 2.064 (2.588)	Data 0.008 (0.085)	Loss 1.1044 (1.0991)	Accuracy 0.000
# Epoch: [0][30/35]	Time 2.431 (2.550)	Data 0.009 (0.060)	Loss 1.0978 (1.0987)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 1.523 (1.523)	Data 0.416 (0.416)	Loss 1.0900 (1.0900)	Accuracy 50.000
# Validation [10/15]	Time 0.511 (0.691)	Data 0.004 (0.042)	Loss 1.1162 (1.0997)	Accuracy 0.000
# Epoch [0]: Validation Accuracy 33.333
# saved_model
# Epoch: [1][0/35]	Time 4.933 (4.933)	Data 0.811 (0.811)	Loss 1.0984 (1.0984)	Accuracy 25.000
# Epoch: [1][10/35]	Time 2.013 (2.692)	Data 0.009 (0.085)	Loss 1.0916 (1.0974)	Accuracy 75.000
# Epoch: [1][20/35]	Time 2.473 (2.453)	Data 0.010 (0.049)	Loss 1.1000 (1.0972)	Accuracy 50.000
# Epoch: [1][30/35]	Time 2.041 (2.452)	Data 0.008 (0.037)	Loss 1.0861 (1.0978)	Accuracy 50.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.882 (0.882)	Data 0.298 (0.298)	Loss 1.0828 (1.0828)	Accuracy 50.000
# Validation [10/15]	Time 0.451 (0.485)	Data 0.004 (0.031)	Loss 1.1312 (1.1007)	Accuracy 0.000
# Epoch [1]: Validation Accuracy 33.333
# saved_model
# Epoch: [2][0/35]	Time 5.038 (5.038)	Data 1.777 (1.777)	Loss 1.0899 (1.0899)	Accuracy 25.000
# Epoch: [2][10/35]	Time 3.130 (3.195)	Data 0.404 (0.259)	Loss 1.0907 (1.0923)	Accuracy 50.000
# Epoch: [2][20/35]	Time 2.307 (2.943)	Data 0.010 (0.243)	Loss 1.0972 (1.0956)	Accuracy 25.000
# Epoch: [2][30/35]	Time 2.007 (2.694)	Data 0.008 (0.168)	Loss 1.0900 (1.0965)	Accuracy 50.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.860 (0.860)	Data 0.297 (0.297)	Loss 1.0769 (1.0769)	Accuracy 50.000
# Validation [10/15]	Time 0.460 (0.491)	Data 0.005 (0.031)	Loss 1.1439 (1.1015)	Accuracy 0.000
# Epoch [2]: Validation Accuracy 33.333
# saved_model
# Epoch: [3][0/35]	Time 4.394 (4.394)	Data 1.039 (1.039)	Loss 1.1105 (1.1105)	Accuracy 25.000
# Epoch: [3][10/35]	Time 3.275 (2.846)	Data 0.009 (0.194)	Loss 1.0885 (1.0949)	Accuracy 25.000
# Epoch: [3][20/35]	Time 2.077 (2.609)	Data 0.008 (0.107)	Loss 1.0650 (1.0962)	Accuracy 75.000
# Epoch: [3][30/35]	Time 1.962 (2.519)	Data 0.008 (0.076)	Loss 1.1321 (1.0927)	Accuracy 0.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 1.401 (1.401)	Data 0.439 (0.439)	Loss 1.0716 (1.0716)	Accuracy 50.000
# Validation [10/15]	Time 0.431 (0.535)	Data 0.004 (0.044)	Loss 1.1557 (1.1025)	Accuracy 0.000
# Epoch [3]: Validation Accuracy 33.333
# saved_model
# Epoch: [4][0/35]	Time 6.359 (6.359)	Data 1.343 (1.343)	Loss 1.0716 (1.0716)	Accuracy 50.000
# Epoch: [4][10/35]	Time 2.951 (3.379)	Data 0.012 (0.397)	Loss 1.1018 (1.1008)	Accuracy 50.000
# Epoch: [4][20/35]	Time 3.207 (2.984)	Data 0.012 (0.250)	Loss 1.0831 (1.0964)	Accuracy 25.000
# Epoch: [4][30/35]	Time 1.990 (2.727)	Data 0.008 (0.172)	Loss 1.1371 (1.0946)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.893 (0.893)	Data 0.293 (0.293)	Loss 1.0668 (1.0668)	Accuracy 50.000
# Validation [10/15]	Time 0.429 (0.480)	Data 0.004 (0.030)	Loss 1.1665 (1.1035)	Accuracy 0.000
# Epoch [4]: Validation Accuracy 33.333
# saved_model
# Epoch: [5][0/35]	Time 4.742 (4.742)	Data 0.734 (0.734)	Loss 1.0991 (1.0991)	Accuracy 25.000
# Epoch: [5][10/35]	Time 2.872 (2.969)	Data 0.008 (0.175)	Loss 1.0663 (1.0931)	Accuracy 50.000
# Epoch: [5][20/35]	Time 1.966 (2.620)	Data 0.008 (0.096)	Loss 1.1176 (1.0977)	Accuracy 0.000
# Epoch: [5][30/35]	Time 2.767 (2.523)	Data 0.022 (0.069)	Loss 1.1393 (1.0937)	Accuracy 0.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.864 (0.864)	Data 0.290 (0.290)	Loss 1.0626 (1.0626)	Accuracy 50.000
# Validation [10/15]	Time 0.438 (1.333)	Data 0.004 (0.039)	Loss 1.1761 (1.1044)	Accuracy 0.000
# Epoch [5]: Validation Accuracy 33.333
# saved_model
# Epoch: [6][0/35]	Time 5.302 (5.302)	Data 0.899 (0.899)	Loss 1.0626 (1.0626)	Accuracy 50.000
# Epoch: [6][10/35]	Time 3.093 (3.417)	Data 0.013 (0.346)	Loss 1.1418 (1.0912)	Accuracy 25.000
# Epoch: [6][20/35]	Time 2.711 (2.951)	Data 0.009 (0.239)	Loss 1.1022 (1.1011)	Accuracy 25.000
# Epoch: [6][30/35]	Time 1.997 (2.721)	Data 0.010 (0.166)	Loss 1.0640 (1.0953)	Accuracy 50.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 1.339 (1.339)	Data 0.475 (0.475)	Loss 1.0586 (1.0586)	Accuracy 50.000
# Validation [10/15]	Time 0.431 (0.549)	Data 0.004 (0.048)	Loss 1.1854 (1.1055)	Accuracy 0.000
# Epoch [6]: Validation Accuracy 33.333
# saved_model
# Epoch: [7][0/35]	Time 4.579 (4.579)	Data 1.292 (1.292)	Loss 1.0587 (1.0587)	Accuracy 50.000
# Epoch: [7][10/35]	Time 2.036 (2.746)	Data 0.008 (0.173)	Loss 1.1262 (1.0779)	Accuracy 25.000
# Epoch: [7][20/35]	Time 1.979 (2.535)	Data 0.009 (0.097)	Loss 1.1788 (1.0847)	Accuracy 0.000
# Epoch: [7][30/35]	Time 2.565 (2.422)	Data 0.009 (0.069)	Loss 1.1253 (1.0920)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.862 (0.862)	Data 0.290 (0.290)	Loss 1.0559 (1.0559)	Accuracy 50.000
# Validation [10/15]	Time 0.657 (0.529)	Data 0.004 (0.030)	Loss 1.1917 (1.1061)	Accuracy 0.000
# Epoch [7]: Validation Accuracy 33.333
# saved_model
# Epoch: [8][0/35]	Time 3.409 (3.409)	Data 0.806 (0.806)	Loss 1.0362 (1.0362)	Accuracy 75.000
# Epoch: [8][10/35]	Time 2.068 (2.752)	Data 0.028 (0.212)	Loss 1.0967 (1.1052)	Accuracy 50.000
# Epoch: [8][20/35]	Time 1.951 (2.461)	Data 0.009 (0.116)	Loss 1.0820 (1.0980)	Accuracy 25.000
# Epoch: [8][30/35]	Time 1.987 (2.472)	Data 0.009 (0.084)	Loss 1.0812 (1.0952)	Accuracy 50.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 1.422 (1.422)	Data 0.390 (0.390)	Loss 1.0528 (1.0528)	Accuracy 50.000
# Validation [10/15]	Time 0.464 (0.611)	Data 0.004 (0.040)	Loss 1.1990 (1.1069)	Accuracy 0.000
# Epoch [8]: Validation Accuracy 33.333
# saved_model
# Epoch: [9][0/35]	Time 3.580 (3.580)	Data 0.763 (0.763)	Loss 1.0998 (1.0998)	Accuracy 25.000
# Epoch: [9][10/35]	Time 1.989 (2.949)	Data 0.008 (0.113)	Loss 1.0991 (1.1057)	Accuracy 25.000
# Epoch: [9][20/35]	Time 2.360 (2.641)	Data 0.009 (0.063)	Loss 1.1259 (1.0986)	Accuracy 25.000
# Epoch: [9][30/35]	Time 2.023 (2.483)	Data 0.009 (0.046)	Loss 1.1048 (1.0946)	Accuracy 50.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.878 (0.878)	Data 0.292 (0.292)	Loss 1.0502 (1.0502)	Accuracy 50.000
# Validation [10/15]	Time 0.434 (0.485)	Data 0.004 (0.030)	Loss 1.2054 (1.1076)	Accuracy 0.000
# Epoch [9]: Validation Accuracy 33.333
# saved_model
# Epoch: [10][0/35]	Time 4.587 (4.587)	Data 1.068 (1.068)	Loss 1.1002 (1.1002)	Accuracy 25.000
# Epoch: [10][10/35]	Time 3.310 (2.826)	Data 0.011 (0.167)	Loss 1.1294 (1.0915)	Accuracy 25.000
# Epoch: [10][20/35]	Time 3.403 (2.601)	Data 0.010 (0.092)	Loss 1.0724 (1.0953)	Accuracy 25.000
# Epoch: [10][30/35]	Time 2.027 (2.520)	Data 0.010 (0.065)	Loss 1.0747 (1.0904)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 1.276 (1.276)	Data 0.407 (0.407)	Loss 1.0482 (1.0482)	Accuracy 50.000
# Validation [10/15]	Time 0.442 (0.532)	Data 0.004 (0.041)	Loss 1.2103 (1.1082)	Accuracy 0.000
# Epoch [10]: Validation Accuracy 33.333
# saved_model
# Epoch: [11][0/35]	Time 3.495 (3.495)	Data 0.757 (0.757)	Loss 1.1292 (1.1292)	Accuracy 25.000
# Epoch: [11][10/35]	Time 2.019 (2.725)	Data 0.009 (0.103)	Loss 1.0761 (1.0783)	Accuracy 50.000
# Epoch: [11][20/35]	Time 2.012 (2.550)	Data 0.009 (0.060)	Loss 1.1036 (1.0971)	Accuracy 50.000
# Epoch: [11][30/35]	Time 2.297 (2.437)	Data 0.009 (0.044)	Loss 1.1023 (1.0913)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.885 (0.885)	Data 0.290 (0.290)	Loss 1.0463 (1.0463)	Accuracy 50.000
# Validation [10/15]	Time 0.676 (0.536)	Data 0.009 (0.031)	Loss 1.2148 (1.1087)	Accuracy 0.000
# Epoch [11]: Validation Accuracy 33.333
# saved_model
# Epoch: [12][0/35]	Time 3.423 (3.423)	Data 0.709 (0.709)	Loss 1.0765 (1.0765)	Accuracy 50.000
# Epoch: [12][10/35]	Time 2.669 (3.331)	Data 0.009 (0.204)	Loss 1.1034 (1.1128)	Accuracy 25.000
# Epoch: [12][20/35]	Time 3.197 (2.902)	Data 0.021 (0.113)	Loss 1.0570 (1.1055)	Accuracy 75.000
# Epoch: [12][30/35]	Time 1.991 (2.665)	Data 0.009 (0.080)	Loss 1.0765 (1.0955)	Accuracy 50.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.891 (0.891)	Data 0.296 (0.296)	Loss 1.0442 (1.0442)	Accuracy 50.000
# Validation [10/15]	Time 0.528 (0.494)	Data 0.004 (0.031)	Loss 1.2202 (1.1094)	Accuracy 0.000
# Epoch [12]: Validation Accuracy 33.333
# saved_model
# Epoch: [13][0/35]	Time 5.601 (5.601)	Data 1.103 (1.103)	Loss 1.0443 (1.0443)	Accuracy 50.000
# Epoch: [13][10/35]	Time 3.226 (2.909)	Data 0.010 (0.290)	Loss 1.1338 (1.0859)	Accuracy 25.000
# Epoch: [13][20/35]	Time 1.999 (2.581)	Data 0.011 (0.157)	Loss 1.0718 (1.0929)	Accuracy 25.000
# Epoch: [13][30/35]	Time 2.002 (2.509)	Data 0.009 (0.111)	Loss 1.1013 (1.0956)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 1.110 (1.110)	Data 0.289 (0.289)	Loss 1.0427 (1.0427)	Accuracy 50.000
# Validation [10/15]	Time 0.455 (0.646)	Data 0.004 (0.033)	Loss 1.2238 (1.1099)	Accuracy 0.000
# Epoch [13]: Validation Accuracy 33.333
# saved_model
# Epoch: [14][0/35]	Time 4.140 (4.140)	Data 0.849 (0.849)	Loss 1.1334 (1.1334)	Accuracy 25.000
# Epoch: [14][10/35]	Time 2.060 (3.002)	Data 0.011 (0.214)	Loss 1.1629 (1.1139)	Accuracy 25.000
# Epoch: [14][20/35]	Time 2.061 (2.695)	Data 0.009 (0.117)	Loss 1.0431 (1.0943)	Accuracy 50.000
# Epoch: [14][30/35]	Time 2.194 (2.532)	Data 0.009 (0.083)	Loss 1.0522 (1.0957)	Accuracy 75.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.881 (0.881)	Data 0.291 (0.291)	Loss 1.0413 (1.0413)	Accuracy 50.000
# Validation [10/15]	Time 0.646 (0.515)	Data 0.009 (0.031)	Loss 1.2275 (1.1103)	Accuracy 0.000
# Epoch [14]: Validation Accuracy 33.333
# saved_model
# Epoch: [15][0/35]	Time 3.652 (3.652)	Data 0.697 (0.697)	Loss 1.0414 (1.0414)	Accuracy 50.000
# Epoch: [15][10/35]	Time 2.041 (2.791)	Data 0.009 (0.105)	Loss 1.0746 (1.0963)	Accuracy 50.000
# Epoch: [15][20/35]	Time 2.023 (2.502)	Data 0.010 (0.060)	Loss 1.1737 (1.0898)	Accuracy 25.000
# Epoch: [15][30/35]	Time 2.057 (2.453)	Data 0.010 (0.044)	Loss 1.0761 (1.0928)	Accuracy 50.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 1.735 (1.735)	Data 0.478 (0.478)	Loss 1.0403 (1.0403)	Accuracy 50.000
# Validation [10/15]	Time 0.454 (0.646)	Data 0.004 (0.051)	Loss 1.2301 (1.1106)	Accuracy 0.000
# Epoch [15]: Validation Accuracy 33.333
# saved_model
# Epoch: [16][0/35]	Time 3.434 (3.434)	Data 0.740 (0.740)	Loss 1.0745 (1.0745)	Accuracy 50.000
# Epoch: [16][10/35]	Time 2.004 (2.742)	Data 0.009 (0.114)	Loss 1.0744 (1.0906)	Accuracy 50.000
# Epoch: [16][20/35]	Time 2.013 (2.549)	Data 0.009 (0.065)	Loss 1.0715 (1.0915)	Accuracy 25.000
# Epoch: [16][30/35]	Time 2.437 (2.440)	Data 0.009 (0.048)	Loss 1.0742 (1.0936)	Accuracy 50.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.890 (0.890)	Data 0.296 (0.296)	Loss 1.0392 (1.0392)	Accuracy 50.000
# Validation [10/15]	Time 0.667 (0.528)	Data 0.004 (0.031)	Loss 1.2327 (1.1110)	Accuracy 0.000
# Epoch [16]: Validation Accuracy 33.333
# saved_model
# Epoch: [17][0/35]	Time 3.690 (3.690)	Data 0.851 (0.851)	Loss 1.1283 (1.1283)	Accuracy 0.000
# Epoch: [17][10/35]	Time 2.340 (3.114)	Data 0.011 (0.279)	Loss 1.1017 (1.0906)	Accuracy 25.000
# Epoch: [17][20/35]	Time 2.478 (2.988)	Data 0.011 (0.200)	Loss 1.2028 (1.0939)	Accuracy 0.000
# Epoch: [17][30/35]	Time 2.001 (2.773)	Data 0.008 (0.139)	Loss 1.1025 (1.0919)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 1.338 (1.338)	Data 0.393 (0.393)	Loss 1.0385 (1.0385)	Accuracy 50.000
# Validation [10/15]	Time 0.445 (0.544)	Data 0.004 (0.039)	Loss 1.2347 (1.1112)	Accuracy 0.000
# Epoch [17]: Validation Accuracy 33.333
# saved_model
# Epoch: [18][0/35]	Time 3.448 (3.448)	Data 0.750 (0.750)	Loss 1.1012 (1.1012)	Accuracy 25.000
# Epoch: [18][10/35]	Time 1.967 (2.710)	Data 0.010 (0.109)	Loss 1.0341 (1.0762)	Accuracy 50.000
# Epoch: [18][20/35]	Time 3.550 (2.852)	Data 0.032 (0.064)	Loss 1.2085 (1.0865)	Accuracy 0.000
# Epoch: [18][30/35]	Time 2.468 (2.655)	Data 0.009 (0.047)	Loss 1.1795 (1.0873)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.890 (0.890)	Data 0.306 (0.306)	Loss 1.0380 (1.0380)	Accuracy 50.000
# Validation [10/15]	Time 0.763 (0.547)	Data 0.017 (0.034)	Loss 1.2358 (1.1114)	Accuracy 0.000
# Epoch [18]: Validation Accuracy 33.333
# saved_model
# Epoch: [19][0/35]	Time 4.360 (4.360)	Data 0.759 (0.759)	Loss 1.1014 (1.1014)	Accuracy 25.000
# Epoch: [19][10/35]	Time 1.982 (3.008)	Data 0.009 (0.118)	Loss 1.1393 (1.0843)	Accuracy 25.000
# Epoch: [19][20/35]	Time 3.317 (2.677)	Data 0.018 (0.067)	Loss 1.0723 (1.0816)	Accuracy 50.000
# Epoch: [19][30/35]	Time 2.036 (2.517)	Data 0.009 (0.049)	Loss 1.1030 (1.0874)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.868 (0.868)	Data 0.288 (0.288)	Loss 1.0375 (1.0375)	Accuracy 50.000
# Validation [10/15]	Time 0.452 (0.484)	Data 0.004 (0.030)	Loss 1.2372 (1.1116)	Accuracy 0.000
# Epoch [19]: Validation Accuracy 33.333
# saved_model
# Epoch: [20][0/35]	Time 5.443 (5.443)	Data 0.976 (0.976)	Loss 1.1094 (1.1094)	Accuracy 50.000
# Epoch: [20][10/35]	Time 2.767 (2.844)	Data 0.010 (0.268)	Loss 1.1388 (1.0902)	Accuracy 25.000
# Epoch: [20][20/35]	Time 2.013 (2.564)	Data 0.009 (0.146)	Loss 1.1012 (1.0942)	Accuracy 25.000
# Epoch: [20][30/35]	Time 2.038 (2.493)	Data 0.031 (0.103)	Loss 1.0639 (1.0921)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.935 (0.935)	Data 0.295 (0.295)	Loss 1.0368 (1.0368)	Accuracy 50.000
# Validation [10/15]	Time 0.434 (0.636)	Data 0.004 (0.030)	Loss 1.2388 (1.1118)	Accuracy 0.000
# Epoch [20]: Validation Accuracy 33.333
# saved_model
# Epoch: [21][0/35]	Time 5.066 (5.066)	Data 0.969 (0.969)	Loss 1.0449 (1.0449)	Accuracy 75.000
# Epoch: [21][10/35]	Time 2.011 (2.861)	Data 0.009 (0.150)	Loss 1.0401 (1.0912)	Accuracy 50.000
# Epoch: [21][20/35]	Time 1.959 (2.607)	Data 0.009 (0.085)	Loss 1.0401 (1.0917)	Accuracy 75.000
# Epoch: [21][30/35]	Time 1.984 (2.458)	Data 0.009 (0.062)	Loss 1.1024 (1.0916)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.875 (0.875)	Data 0.295 (0.295)	Loss 1.0361 (1.0361)	Accuracy 50.000
# Validation [10/15]	Time 0.433 (0.481)	Data 0.004 (0.031)	Loss 1.2407 (1.1121)	Accuracy 0.000
# Epoch [21]: Validation Accuracy 33.333
# saved_model
# Epoch: [22][0/35]	Time 3.992 (3.992)	Data 1.039 (1.039)	Loss 1.2035 (1.2035)	Accuracy 0.000
# Epoch: [22][10/35]	Time 2.960 (2.823)	Data 0.009 (0.194)	Loss 1.0128 (1.1058)	Accuracy 75.000
# Epoch: [22][20/35]	Time 1.978 (2.511)	Data 0.010 (0.107)	Loss 1.0719 (1.0932)	Accuracy 50.000
# Epoch: [22][30/35]	Time 2.525 (2.504)	Data 0.009 (0.078)	Loss 1.1399 (1.0925)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 1.344 (1.344)	Data 0.389 (0.389)	Loss 1.0354 (1.0354)	Accuracy 50.000
# Validation [10/15]	Time 0.448 (0.544)	Data 0.004 (0.039)	Loss 1.2425 (1.1124)	Accuracy 0.000
# Epoch [22]: Validation Accuracy 33.333
# saved_model
# Epoch: [23][0/35]	Time 3.569 (3.569)	Data 0.743 (0.743)	Loss 1.0730 (1.0730)	Accuracy 50.000
# Epoch: [23][10/35]	Time 1.980 (2.724)	Data 0.009 (0.110)	Loss 1.0378 (1.1068)	Accuracy 50.000
# Epoch: [23][20/35]	Time 2.024 (2.531)	Data 0.009 (0.063)	Loss 1.0382 (1.1024)	Accuracy 50.000
# Epoch: [23][30/35]	Time 2.022 (2.414)	Data 0.010 (0.046)	Loss 1.0352 (1.0948)	Accuracy 50.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.880 (0.880)	Data 0.293 (0.293)	Loss 1.0347 (1.0347)	Accuracy 50.000
# Validation [10/15]	Time 0.441 (0.482)	Data 0.004 (0.030)	Loss 1.2442 (1.1125)	Accuracy 0.000
# Epoch [23]: Validation Accuracy 33.333
# saved_model
# Epoch: [24][0/35]	Time 4.282 (4.282)	Data 1.041 (1.041)	Loss 0.9769 (0.9769)	Accuracy 100.000
# Epoch: [24][10/35]	Time 2.540 (2.846)	Data 0.008 (0.173)	Loss 1.0011 (1.0634)	Accuracy 75.000
# Epoch: [24][20/35]	Time 1.969 (2.523)	Data 0.009 (0.096)	Loss 1.1761 (1.0768)	Accuracy 0.000
# Epoch: [24][30/35]	Time 2.007 (2.527)	Data 0.011 (0.069)	Loss 1.1432 (1.0867)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 1.395 (1.395)	Data 0.393 (0.393)	Loss 1.0348 (1.0348)	Accuracy 50.000
# Validation [10/15]	Time 0.609 (0.800)	Data 0.006 (0.041)	Loss 1.2440 (1.1125)	Accuracy 0.000
# Epoch [24]: Validation Accuracy 33.333
# saved_model
# Epoch: [25][0/35]	Time 6.235 (6.235)	Data 1.760 (1.760)	Loss 1.1016 (1.1016)	Accuracy 25.000
# Epoch: [25][10/35]	Time 3.084 (3.024)	Data 0.015 (0.284)	Loss 1.0739 (1.0912)	Accuracy 50.000
# Epoch: [25][20/35]	Time 2.043 (2.631)	Data 0.010 (0.154)	Loss 1.0445 (1.0894)	Accuracy 75.000
# Epoch: [25][30/35]	Time 2.066 (2.539)	Data 0.009 (0.108)	Loss 1.0727 (1.0935)	Accuracy 50.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 2.223 (2.223)	Data 0.764 (0.764)	Loss 1.0346 (1.0346)	Accuracy 50.000
# Validation [10/15]	Time 1.025 (0.858)	Data 0.026 (0.078)	Loss 1.2446 (1.1126)	Accuracy 0.000
# Epoch [25]: Validation Accuracy 33.333
# saved_model
# Epoch: [26][0/35]	Time 5.515 (5.515)	Data 1.052 (1.052)	Loss 1.2068 (1.2068)	Accuracy 0.000
# Epoch: [26][10/35]	Time 2.046 (3.406)	Data 0.009 (0.208)	Loss 1.1358 (1.1030)	Accuracy 0.000
# Epoch: [26][20/35]	Time 1.984 (2.892)	Data 0.009 (0.114)	Loss 1.1380 (1.1022)	Accuracy 25.000
# Epoch: [26][30/35]	Time 2.314 (2.667)	Data 0.009 (0.080)	Loss 1.1405 (1.0927)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.855 (0.855)	Data 0.281 (0.281)	Loss 1.0339 (1.0339)	Accuracy 50.000
# Validation [10/15]	Time 0.682 (0.530)	Data 0.004 (0.029)	Loss 1.2463 (1.1128)	Accuracy 0.000
# Epoch [26]: Validation Accuracy 33.333
# saved_model
# Epoch: [27][0/35]	Time 3.367 (3.367)	Data 0.692 (0.692)	Loss 1.1402 (1.1402)	Accuracy 25.000
# Epoch: [27][10/35]	Time 2.086 (2.698)	Data 0.009 (0.167)	Loss 1.1407 (1.0911)	Accuracy 25.000
# Epoch: [27][20/35]	Time 1.992 (2.440)	Data 0.011 (0.092)	Loss 1.1410 (1.0928)	Accuracy 25.000
# Epoch: [27][30/35]	Time 3.063 (2.431)	Data 0.008 (0.066)	Loss 1.1416 (1.0905)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.841 (0.841)	Data 0.285 (0.285)	Loss 1.0337 (1.0337)	Accuracy 50.000
# Validation [10/15]	Time 0.455 (0.490)	Data 0.004 (0.030)	Loss 1.2469 (1.1129)	Accuracy 0.000
# Epoch [27]: Validation Accuracy 33.333
# saved_model
# Epoch: [28][0/35]	Time 4.874 (4.874)	Data 0.739 (0.739)	Loss 1.0337 (1.0337)	Accuracy 50.000
# Epoch: [28][10/35]	Time 1.971 (2.662)	Data 0.012 (0.106)	Loss 1.1003 (1.1011)	Accuracy 25.000
# Epoch: [28][20/35]	Time 1.990 (2.479)	Data 0.009 (0.060)	Loss 1.1409 (1.0963)	Accuracy 25.000
# Epoch: [28][30/35]	Time 3.293 (2.411)	Data 0.033 (0.045)	Loss 1.1424 (1.0910)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.850 (0.850)	Data 0.300 (0.300)	Loss 1.0336 (1.0336)	Accuracy 50.000
# Validation [10/15]	Time 0.747 (0.611)	Data 0.020 (0.038)	Loss 1.2473 (1.1129)	Accuracy 0.000
# Epoch [28]: Validation Accuracy 33.333
# saved_model
# Epoch: [29][0/35]	Time 4.103 (4.103)	Data 1.270 (1.270)	Loss 1.0040 (1.0040)	Accuracy 75.000
# Epoch: [29][10/35]	Time 1.956 (2.818)	Data 0.010 (0.265)	Loss 1.0698 (1.0544)	Accuracy 50.000
# Epoch: [29][20/35]	Time 3.333 (2.561)	Data 0.011 (0.145)	Loss 1.1442 (1.0779)	Accuracy 25.000
# Epoch: [29][30/35]	Time 2.020 (2.484)	Data 0.009 (0.102)	Loss 1.1391 (1.0949)	Accuracy 25.000
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:259: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   logit_all.append(torch.tensor(logit.data.cpu()))
# /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/main.py:260: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   target_all.append(torch.tensor(target.data.cpu()))
# Validation [0/15]	Time 0.949 (0.949)	Data 0.290 (0.290)	Loss 1.0336 (1.0336)	Accuracy 50.000
# Validation [10/15]	Time 0.435 (0.491)	Data 0.004 (0.030)	Loss 1.2470 (1.1130)	Accuracy 0.000
# Epoch [29]: Validation Accuracy 33.333
# saved_model

# %% [markdown]
# # Model Evaluation
#   * Note: Modify config_name and model_file_name accordingly.

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import numpy as np
import matplotlib.pyplot as plt
from torch.autograd import Variable
import torch.nn.functional as F
import os
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
# from scipy import interp
import matplotlib.pyplot as plt
from numpy.random import permutation
import yaml

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
config_name = 'config_200_alex.yaml'
with open(os.path.join('./'+config_name), 'r') as f:
    cfg = yaml.safe_load(f)

# %%
from datasets.adni_3d import ADNI_3D
from models.build_model import build_model

# %% [markdown]
# ## Config the location of preprocessed data and corresponding TSV files

# %%
dir_to_scans = '/content/gdrive/My Drive/cs598_DL4H/ADNI_processed_200/subjects'
dir_to_tsv = '/content/gdrive/My Drive/cs598_DL4H/ADNI_converted_meta_all/sample_200'
Test_dataset = ADNI_3D(dir_to_scans, dir_to_tsv, mode = 'Test',  n_label = cfg['model']['n_label'])
Test_loader = torch.utils.data.DataLoader(
        Test_dataset, batch_size=cfg['data']['val_batch_size'], shuffle=False,
        num_workers=cfg['data']['workers'], pin_memory=True)

# %%
category = ['CN','MCI','AD']

# %%
def visualize_example(Test_dataset,sub_id):
    plt.figure(figsize=(10, 10))
    image = Test_dataset.__getitem__(sub_id)[0][0]
    plt.subplot(1, 3, 1)
    plt.imshow(np.rot90(image[26,:,:]),cmap = 'gray')
    plt.ylabel('Subject '+str(sub_id) + ' in Test dataset', fontsize=10)
    plt.title('Class: '+category[Test_dataset.__getitem__(sub_id)[1]] , fontsize=10)
    plt.subplot(1, 3, 2)
    plt.imshow(np.rot90(image[:,57,:]),cmap = 'gray')
    plt.title('Class: '+category[Test_dataset.__getitem__(sub_id)[1]], fontsize=10)
    plt.subplot(1, 3, 3)
    plt.imshow(np.rot90(image[:,:,50]),cmap = 'gray')
    plt.title('Class: '+category[Test_dataset.__getitem__(sub_id)[1]], fontsize=10)

# %%
visualize_example(Test_dataset,20)

# %%
from sklearn.metrics import confusion_matrix
def balanced_accuracy_score(y_true, y_pred, sample_weight=None,
                            adjusted=False):
    C = confusion_matrix(y_true, y_pred, sample_weight=sample_weight)
    with np.errstate(divide='ignore', invalid='ignore'):
        per_class = np.diag(C) / C.sum(axis=1)
    if np.any(np.isnan(per_class)):
        warnings.warn('y_pred contains classes not in y_true')
        per_class = per_class[~np.isnan(per_class)]
    score = np.mean(per_class)
    if adjusted:
        n_classes = len(per_class)
        chance = 1 / n_classes
        score -= chance
        score /= 1 - chance
    return score

# %%
def calc_aucs(target_all,logit_all):
    y = label_binarize(target_all, classes=[0,1,2])
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for k in range(cfg['model']['n_label']):
        fpr[k], tpr[k], _ = roc_curve(y[:, k], logit_all[:, k])
        roc_auc[k] = auc(fpr[k], tpr[k])

    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y.ravel(), logit_all.ravel())
    roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])
    all_fpr = np.unique(np.concatenate([fpr[k] for k in range(cfg['model']['n_label'])]))

    mean_tpr = np.zeros_like(all_fpr)
    for k in range(cfg['model']['n_label']):
        mean_tpr += np.interp(all_fpr, fpr[k], tpr[k])

    # Finally average it and compute AUC
    mean_tpr /= cfg['model']['n_label']

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
    return roc_auc

# %%
def plot_rocs(target_all,logit_all):
    y = label_binarize(target_all, classes=[0,1,2])
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for k in range(cfg['model']['n_label']):
        fpr[k], tpr[k], _ = roc_curve(y[:, k], logit_all[:, k])
        roc_auc[k] = auc(fpr[k], tpr[k])

    # Compute micro-average ROC curve and ROC area
    fpr["micro"], tpr["micro"], _ = roc_curve(y.ravel(), logit_all.ravel())
    roc_auc[k+1] = auc(fpr["micro"], tpr["micro"])
    all_fpr = np.unique(np.concatenate([fpr[k] for k in range(cfg['model']['n_label'])]))

    mean_tpr = np.zeros_like(all_fpr)
    for k in range(cfg['model']['n_label']):
        mean_tpr += np.interp(all_fpr, fpr[k], tpr[k])

    # Finally average it and compute AUC
    mean_tpr /= cfg['model']['n_label']

    fpr["macro"] = all_fpr
    tpr["macro"] = mean_tpr
    roc_auc[k+2] = auc(fpr["macro"], tpr["macro"])
    plotting_fpr = []
    plotting_tpr = []
    for k in range(cfg['model']['n_label']):
        plotting_fpr.append(fpr[k])
        plotting_tpr.append(tpr[k])
    plotting_fpr += [fpr["micro"], fpr["macro"]]
    plotting_tpr += [tpr["micro"], tpr["macro"]]
    auc_outs = [plotting_fpr, plotting_tpr, roc_auc]
    name = ['CN vs all ','MCI vs all ', 'AD vs all ', 'Micro ', 'Macro ']
    from itertools import cycle
    colors = cycle(['aqua', 'darkorange', 'cornflowerblue','navy','deeppink'])
    plt.figure()
    for i, color in zip(range(len(auc_outs[0])), colors):
        plt.plot(auc_outs[0][i], auc_outs[1][i], color=color, lw=2, label=name[i] + 'ROC curve (area = %0.2f)' % auc_outs[2][i])
    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('AUC curves')
    plt.legend(loc="lower right")

# %%
def run_epoch(model,val_loader,use_age=False):
    logit_all = []
    target_all = []
    mmse_all = []
    patient_idx_all = []
    cdr_all = []
    for i, (input, target, patient_idx, mmse, cdr_sub, age_id) in enumerate(val_loader):
        if i % 20 == 0:
            print('Iteration: ',i)
        input = input.to(device)
        target = target.to(device)
        if use_age:
            age_id = age_id.to(device)
        else:
            age_id = None
        logit = model(input,age_id)
        logit_all.append(logit.data.cpu())
        target_all.append(target.data.cpu())
        mmse_all.append(mmse.cpu())
        patient_idx_all.append(patient_idx.cpu())
        cdr_all.append(cdr_sub.cpu())

    logit_all_catted = torch.cat(logit_all)
    target_all_catted = torch.cat(target_all)
    mmse_all_catted = torch.cat(mmse_all)
    patient_idx_all_catted = torch.cat(patient_idx_all)
    cdr_all_catted = torch.cat(cdr_all)
    return logit_all_catted.numpy(), target_all_catted.numpy(), mmse_all_catted.numpy(), patient_idx_all_catted.numpy(), cdr_all_catted.numpy()

# %%
def evaluation_models(model_name,data_loader, expansion_list = [1],  num_trails = 10,percentage = 0.8, use_age = False, norm_type= 'Instance'):

    all_acc = np.zeros((len(expansion_list),num_trails))
    all_balanced_acc = np.zeros((len(expansion_list),num_trails))
    all_auc = []
    for i,ep in enumerate(expansion_list):
        cfg['model']['expansion'] = ep
        cfg['model']['norm_type'] = norm_type
        model = build_model(cfg)
        best_model_dir = './saved_model/'
        pretrained_dict = torch.load(best_model_dir+model_name + '_model_low_loss.pth.tar',map_location='cpu', weights_only=False)['state_dict']
        old_ks = list(pretrained_dict.keys()).copy()
        model_dict = model.state_dict()
        pretrained_dict = {k[6:]: v for k, v in pretrained_dict.items() if (k[6:]in model_dict.keys())}
        model_dict.update(pretrained_dict)
        model.load_state_dict(model_dict)
        model = model.to(device)
        model = model.eval()
        logit_all,target_all,_,_,_= run_epoch(model, data_loader, use_age)
        #print(F.softmax(torch.tensor(logit_all[0:20]),dim=1))
        tes_auc = []
        for tes in range(num_trails):
            rand_idex = permutation(range(len(target_all)))[:int(percentage*len(target_all))]
            target_test = target_all[rand_idex]
            pred_test = np.argmax(logit_all,1)[rand_idex]
            logit_test = logit_all[rand_idex]
            all_acc[i,tes] =accuracy_score(target_test, pred_test)
            all_balanced_acc[i,tes] =balanced_accuracy_score(target_test, pred_test)
            tes_auc.append(calc_aucs(target_test,logit_test))
        plot_rocs(target_test,logit_test)
        all_auc.append(tes_auc)
        print(old_ks)
        print(list(pretrained_dict.keys()))
    return all_acc, all_balanced_acc, all_auc

# %%
def test_model(all_acc, all_balanced_acc,all_auc):
    for w_k in range(len(all_acc)):
        print('Mean Acc ', np.mean(all_acc[w_k]),'\t')
        print('STD Acc ', np.std(all_acc[w_k]),'\t')
        print('Mean Balanced Acc ', np.mean(all_balanced_acc[w_k]),'\t')
        print('std Balanced Acc ', np.std(all_balanced_acc[w_k]),'\t')
        avg_micro = []
        avg_macro = []
        for d in all_auc[w_k]:
            avg_micro.append( d['micro'])
            avg_macro.append( d['macro'])
        print('Micro mean: ',np.mean(avg_micro))
        print('Micro std: ', np.std(avg_micro))
        print('Macro mean: ',np.mean(avg_macro))
        print('Macro std: ',np.std(avg_macro))

# %% [markdown]
# ## Load the trained model
#    * The trained models are saved under /content/gdrive/My Drive/cs598_DL4H/CNN_design_for_AD/saved_model

# %%
model = build_model(cfg)
# model_file_name = 'age_expansion_8' # Author's model
# model_file_name = "200_pooling_age_train_perc_100.0_expansion_0"
# model_file_name = "200_pooling_age_train_perc_100.0_expansion_8"
model_file_name = "alexNet_pooling_train_perc_100.0_expansion_0"
# Out:
# Baseline AlexNet Archetecture!

# %%
all_acc, all_balanced_acc, all_auc = evaluation_models(model_file_name,Test_loader, expansion_list = [8], use_age = True, norm_type= 'Instance')
# Out:
# Baseline AlexNet Archetecture!
# Iteration:  0
# ['model.image_embedding_model.features.0.weight', 'model.image_embedding_model.features.0.bias', 'model.image_embedding_model.features.3.weight', 'model.image_embedding_model.features.3.bias', 'model.image_embedding_model.features.6.weight', 'model.image_embedding_model.features.6.bias', 'model.image_embedding_model.features.8.weight', 'model.image_embedding_model.features.8.bias', 'model.image_embedding_model.features.10.weight', 'model.image_embedding_model.features.10.bias', 'model.image_embedding_model.classifier.1.weight', 'model.image_embedding_model.classifier.1.bias', 'model.image_embedding_model.classifier.4.weight', 'model.image_embedding_model.classifier.4.bias', 'model.image_embedding_model.classifier.6.weight', 'model.image_embedding_model.classifier.6.bias', 'model.classifier.classifier.LinearClassifier.weight', 'model.classifier.classifier.LinearClassifier.bias', 'model.classifier.classifier.LinearClassifier2.weight', 'model.classifier.classifier.LinearClassifier2.bias']
# ['image_embedding_model.features.0.weight', 'image_embedding_model.features.0.bias', 'image_embedding_model.features.3.weight', 'image_embedding_model.features.3.bias', 'image_embedding_model.features.6.weight', 'image_embedding_model.features.6.bias', 'image_embedding_model.features.8.weight', 'image_embedding_model.features.8.bias', 'image_embedding_model.features.10.weight', 'image_embedding_model.features.10.bias', 'image_embedding_model.classifier.1.weight', 'image_embedding_model.classifier.1.bias', 'image_embedding_model.classifier.4.weight', 'image_embedding_model.classifier.4.bias', 'image_embedding_model.classifier.6.weight', 'image_embedding_model.classifier.6.bias', 'classifier.classifier.LinearClassifier.weight', 'classifier.classifier.LinearClassifier.bias', 'classifier.classifier.LinearClassifier2.weight', 'classifier.classifier.LinearClassifier2.bias']

# %%
test_model(all_acc, all_balanced_acc,all_auc)
# Out:
# Mean Acc  0.35833333333333334
# STD Acc  0.03333333333333335
# Mean Balanced Acc  0.33333333333333337
# std Balanced Acc  5.551115123125783e-17
# Micro mean:  0.5442708333333333
# Micro std:  0.0430576556387472
# Macro mean:  0.6437151438517446
# Macro std:  0.0292146001631933
